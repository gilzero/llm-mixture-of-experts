# %%
# !pip install langchain-openai langchain-anthropic langchain-xai langchain-google-genai altair --quiet

# %%
# !pip install langchain-openai langchain-anthropic langchain-xai langchain-google-genai altair --quiet

import os
from google.colab import userdata
import altair as alt
import pandas as pd
from IPython.display import display

if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
if not os.environ.get("ANTHROPIC_API_KEY"):
    os.environ["ANTHROPIC_API_KEY"] = userdata.get("ANTHROPIC_API_KEY")
if not os.environ.get("XAI_API_KEY"):
    os.environ["XAI_API_KEY"] = userdata.get("XAI_API_KEY")
if not os.environ.get("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %%
import os
from google.colab import userdata
from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic
from langchain_xai import ChatXAI
from langchain_google_genai import ChatGoogleGenerativeAI

if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
if not os.environ.get("ANTHROPIC_API_KEY"):
    os.environ["ANTHROPIC_API_KEY"] = userdata.get("ANTHROPIC_API_KEY")
if not os.environ.get("XAI_API_KEY"):
    os.environ["XAI_API_KEY"] = userdata.get("XAI_API_KEY")
if not os.environ.get("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %%
# define expert styles

expert_styles = {
    "technical": "Focus on detailed technical explanations.",
    "creative": "Use imaginative, broad storytelling approaches.",
    "business": "Emphasize strategic and economic impacts."
}


def create_expert(model, style, temperature=0, max_tokens=256):
    style_prompt = f"You are an expert with style: {style}."
    def invoke_expert(query):
        return model.invoke([("system", style_prompt), ("user", query)]).content
    return invoke_expert

# %%
# Create experts with different styles

openai_expert = create_expert(ChatOpenAI(model="gpt-4o", temperature=0, max_tokens=256), "technical")

anthropic_expert = create_expert(ChatAnthropic(model="claude-3-5-haiku-20241022", temperature=0, max_tokens=256), "creative")

xai_expert = create_expert(ChatXAI(model="grok-beta", temperature=0, max_tokens=256), "business")

supervisor_model = ChatGoogleGenerativeAI(model="gemini-2.0-flash-exp", temperature=0, max_tokens=512)

# %%
def get_expert_responses(query):
    # Step 1: Gathering Expert Insights
    print("🔍 Gathering insights from our AI experts...")
    return {
        "OpenAI": openai_expert(query),
        "Anthropic": anthropic_expert(query),
        "xAI": xai_expert(query)
    }

def invoke_supervisor(role, content, task):
    # Step: Invoking the Supervisor AI
    print(f"🧑‍💼 Invoking Supervisor AI as {role} to {task}")
    prompt = [
        ("system", f"You are a supervisor {role}. {task}"),
        ("user", content)
    ]
    return supervisor_model.invoke(prompt).content

def consensus_analysis(responses):
    # Step 2: Consensus Analysis
    print("\n🔄 Analyzing consensus among expert responses...")
    task = "Analyze the following experts' responses. Provide a consensus analysis and highlight disagreements."
    content = "\n".join([f"{name}: {resp}" for name, resp in responses.items()])
    return invoke_supervisor("analyzing responses", content, task)

def generate_charts_mindmaps(responses):
    # Step 3: Visual Representation
    print("\n📊 Generating charts and mindmaps for visual representation...")
    task = "Generate useful charts or mindmap descriptions in concise text."
    content = f"Content:\n\n{responses}"
    return invoke_supervisor("generating charts or mindmaps", content, task)

def analyze_tools(responses):
    # Step 4: Detailed Analysis
    print("\n🔎 Running analysis tools on the responses...")
    task = (
        "Perform sentiment analysis, bias detection, uncertainty highlighting, "
        "and jargon explanation. Separate each analysis by sections."
    )
    content = f"Text:\n\n{responses}"
    return invoke_supervisor("performing analysis tools", content, task)

def suggest_related_questions(responses):
    # Step 5: Encouraging Further Exploration
    print("\n❓ Suggesting questions to dive deeper...")
    task = "Provide related questions for deeper learning."
    content = f"Text:\n\n{responses}"
    return invoke_supervisor("suggesting learning questions", content, task)

def meta_analysis(responses):
    # Step 6: High-Level Analysis
    print("\n🧠 Performing meta-analysis on the collected data...")
    task = "Evaluate quality metrics and perform pattern recognition."
    content = f"Text:\n\n{responses}"
    return invoke_supervisor("performing meta-analysis", content, task)

def run_full_workflow(query):
    # Starting the full analysis workflow
    print("\n🚀 Initiating the full analysis workflow...")
    responses = get_expert_responses(query)
    combined_responses = "\n".join([f"{name}:\n{resp}" for name, resp in responses.items()])

    return {
        **responses,
        "Consensus_Analysis": consensus_analysis(responses),
        "Charts_Mindmaps": generate_charts_mindmaps(combined_responses),
        "Analysis_Tools": analyze_tools(combined_responses),
        "Related_Questions": suggest_related_questions(combined_responses),
        "Meta_Analysis": meta_analysis(combined_responses)
    }

# %%
# Run full workflow . Take some times.

query_example = "Explain how generative AI impacts modern software development."
query_example = "Explain how Data analysis and data science are different"
results = run_full_workflow(query_example)
# Out:
# 🚀 Initiating the full analysis workflow...
# 🔍 Gathering insights from our AI experts...
#
# 🔄 Analyzing consensus among expert responses...
# 🧑‍💼 Invoking Supervisor AI as analyzing responses to Analyze the following experts' responses. Provide a consensus analysis and highlight disagreements.
#
# 📊 Generating charts and mindmaps for visual representation...
# 🧑‍💼 Invoking Supervisor AI as generating charts or mindmaps to Generate useful charts or mindmap descriptions in concise text.
#
# 🔎 Running analysis tools on the responses...
# 🧑‍💼 Invoking Supervisor AI as performing analysis tools to Perform sentiment analysis, bias detection, uncertainty highlighting, and jargon explanation. Separate each analysis by sections.
#
# ❓ Suggesting questions to dive deeper...
# 🧑‍💼 Invoking Supervisor AI as suggesting learning questions to Provide related questions for deeper learning.
#
# 🧠 Performing meta-analysis on the collected data...
# 🧑‍💼 Invoking Supervisor AI as performing meta-analysis to Evaluate quality metrics and perform pattern recognition.

# %%
def display_results(results, query_example):
    # Header for the entire output with some flair
    print("=== ✨ Workflow Results ✨ ===")
    print(f"🔍 Query: {query_example}\n")

    # 1. Display Expert Responses with Icons
    print("=== 🧠 Expert Responses ===")
    expert_icons = {"OpenAI": "🤖", "Anthropic": "🧠", "xAI": "🧬"}
    for expert, response in {k: v for k, v in results.items() if k.endswith("Response")}.items():
        print(f"{expert_icons.get(expert, '👤')} {expert.replace('_Response', '')}:\n{response}\n")

    # 2. Display Other Sections with Clean Headings and Icons
    sections = {
        "Charts_Mindmaps": ("📊", "Charts and Mindmaps"),
        "Analysis_Tools": ("🔬", "Analysis Tools"),
        "Related_Questions": ("❓", "Related Questions"),
        "Meta_Analysis": ("🧠", "Meta Analysis"),
        "Consensus_Analysis": ("🔄", "Consensus Analysis")
    }

    for key, (icon, title) in sections.items():
        if key in results:
            print(f"=== {icon} {title} ===")
            # Split the content into lines for better readability
            for line in results[key].split('\n'):
                print(line)
            print("\n")

# Example usage
# query_example = "Explain how generative AI impacts modern software development."
# results = run_full_workflow(query_example)
display_results(results, query_example)
# Out:
# === ✨ Workflow Results ✨ ===
# 🔍 Query: Explain how Data analysis and data science are different
#
# === 🧠 Expert Responses ===
# === 📊 Charts and Mindmaps ===
# Okay, here are descriptions for charts or mindmaps summarizing the differences between Data Analysis and Data Science, based on the provided text:
#
# **Chart 1: Venn Diagram**
#
# *   **Description:** A Venn diagram with two overlapping circles. One circle is labeled "Data Analysis" and the other "Data Science." The overlapping section represents shared skills and techniques.
#     *   **Data Analysis Circle:**  Key points: "Focus: Insights from existing data," "Scope: Specific questions," "Techniques: Descriptive statistics, visualization," "Outcome: Reports, dashboards."
#     *   **Data Science Circle:** Key points: "Focus: Data-driven products," "Scope: Predictive modeling," "Techniques: Machine learning, advanced algorithms," "Outcome: AI models, predictive systems."
#     *   **Overlap:**  Key points: "Data manipulation," "Statistical methods," "Programming (Python, R)."
#
# **Chart 2:  Side-by-Side Comparison Table**
#
# *   **Description:** A table with two columns, "Data Analysis" and "Data Science," and rows for key comparison points.
#     *   **Rows:**
#         *   **Objective:** (Data Analysis: Extract insights, answer questions; Data Science: Create data-driven products, predict future)
#         *   **Scope:** (Data Analysis: Focused, specific; Data Science: Broad, predictive)
#         *   **Techniques:** (Data Analysis: Descriptive statistics, visualization; Data Science: Machine learning, advanced algorithms)
#         *   **Tools:** (Data Analysis: Excel, SQL, BI tools; Data Science: Python, R, advanced programming)
#         *   **Outcome:** (Data Analysis: Reports, dashboards; Data Science: AI models, predictive systems)
#         *   **Skillset:** (Data Analysis: Analytical, statistical; Data Science: Interdisciplinary, advanced technical)
#
# **Chart 3: Mind Map**
#
# *   **Description:** A central node labeled "Data Analysis vs. Data Science." Two main branches extend from it.
#     *   **Branch 1: Data Analysis:**
#         *   Sub-branches: "Objective: Understand past," "Scope: Specific," "Techniques: Descriptive," "Tools: SQL, Excel," "Outcome: Reports," "Skills: Statistical, analytical."
#     *   **Branch 2: Data Science:**
#         *   Sub-branches: "Objective: Predict future," "Scope: Broad,"
#
#
# === 🔬 Analysis Tools ===
# Okay, let's break down this text with sentiment analysis, bias detection, uncertainty highlighting, and jargon explanation.
#
# ## Sentiment Analysis
#
# Overall, the sentiment of the text is **neutral and objective**. It aims to provide a factual comparison between data analysis and data science. There are no strong positive or negative emotions expressed. The language is descriptive and informative, focusing on the differences in scope, techniques, objectives, and outcomes of each field.
#
# *   **OpenAI:** The tone is very formal and structured, using numbered lists and clear headings.
# *   **Anthropic:** The tone is more creative and metaphorical, using analogies like "detective" and "visionary architect." This adds a slightly more engaging feel but still remains neutral in sentiment.
# *   **xAI:** The tone is similar to OpenAI, using a structured approach with headings and bullet points. It is also neutral and objective.
#
# ## Bias Detection
#
# There is minimal overt bias in the text. However, some subtle biases might be present:
#
# *   **Implicit Hierarchy:** The way the information is presented might subtly imply that data science is "more advanced" or "more important" than data analysis. This is particularly noticeable in the Anthropic section, where data science is described as "visionary architect" and data analysis as "detective." This could be interpreted as a bias towards the more complex and future-oriented field.
# *   **Tool Emphasis:** The text lists specific tools for each field. While this is informative, it could inadvertently create a bias towards certain technologies. For example, the emphasis on Python and R for data science might suggest that these are the only valid tools, which is not necessarily true.
# *   **Scope Framing:** The framing of data science as "predictive and prescriptive" and data analysis as "descriptive and diagnostic" could be seen as a bias towards future-oriented work. This might undervalue the importance of understanding past and present data.
#
# **Mitigation:** It's important to note that these are subtle biases and not necessarily intentional. The text is primarily descriptive. However, readers should be aware that the way information is framed can influence perception.
#
# ## Uncertainty Highlighting
#
# There is very little uncertainty expressed in the text. The information is presented as factual and definitive. However, some areas where uncertainty could be considered:
#
# *   **"Typical Tasks":** The lists of typical tasks are not exhaustive and might not apply to all situations. The use of "typical" implies that there are
#
#
# === ❓ Related Questions ===
# Okay, here are some learning questions based on the provided text, designed to encourage deeper understanding and critical thinking about the differences between data analysis and data science. I've categorized them for clarity:
#
# **Understanding Core Concepts:**
#
# *   **Question 1:** The texts mention that data analysis is often about "what happened" and "why it happened," while data science is about "predicting future scenarios." Can you provide a real-world example of a business problem where both data analysis and data science would be used, and explain how each would contribute?
#     *   **Deeper Learning:** This question encourages applying the concepts to a practical situation, highlighting the complementary nature of the two fields.
# *   **Question 2:** All three texts mention "descriptive statistics" as a key technique in data analysis. What are some examples of descriptive statistics, and why are they so important for understanding data?
#     *   **Deeper Learning:** This prompts a deeper dive into a specific technique, encouraging understanding of its purpose and application.
# *   **Question 3:** The texts list various tools used in both data analysis and data science. Why are tools like Python and R more commonly associated with data science, while tools like Excel are more often used in data analysis?
#     *   **Deeper Learning:** This question encourages thinking about the capabilities of different tools and why they are suited to different tasks.
# *   **Question 4:** The Anthropic text uses the metaphors of a "detective" for data analysis and a "visionary architect" for data science. How do these metaphors help to illustrate the differences in their roles and objectives?
#     *   **Deeper Learning:** This encourages thinking about the abstract concepts through the lens of metaphors, enhancing understanding.
#
# **Comparing and Contrasting:**
#
# *   **Question 5:** The texts highlight that data science involves "predictive modeling" and "machine learning." How do these techniques differ from the statistical methods used in data analysis, and why are they important for future-oriented tasks?
#     *   **Deeper Learning:** This question encourages a deeper understanding of the techniques used in data science and their purpose.
# *   **Question 6:** The xAI text mentions that data analysis focuses on "cleaning" and "transforming" data. Why is this step so crucial, and how does it impact the quality of the insights derived from the data?
#     *   **Deeper Learning:** This question highlights the importance of data
#
#
# === 🧠 Meta Analysis ===
# Okay, let's analyze these three texts describing the differences between Data Analysis and Data Science. Here's a breakdown of my evaluation, focusing on quality metrics and pattern recognition:
#
# **Overall Quality Assessment:**
#
# *   **Clarity and Conciseness:** All three texts do a reasonably good job of explaining the core differences. OpenAI's is structured with numbered points, Anthropic uses a creative analogy, and xAI uses a more traditional breakdown. All are relatively easy to understand.
# *   **Accuracy:** The information presented is generally accurate and aligns with common understanding of the two fields. There are no major factual errors.
# *   **Completeness:** Each text covers the key aspects of both data analysis and data science, including objectives, scope, techniques, tools, outcomes, and required skill sets.
# *   **Consistency:** There is a high degree of consistency across the three texts in terms of the core differences they highlight. They all agree on the fundamental distinctions.
# *   **Bias:** There is no apparent bias in any of the texts. They present the information objectively.
#
# **Pattern Recognition and Key Themes:**
#
# Here are the recurring themes and patterns I've identified:
#
# 1.  **Focus on Past vs. Future:**
#     *   **Data Analysis:** Consistently described as focused on understanding *past* or *current* data. It's about what *has happened* and *why*. The goal is to extract insights from existing data.
#     *   **Data Science:** Described as forward-looking, focusing on *predicting future outcomes* and building models. It's about what *could happen* and how to influence it.
#
# 2.  **Scope and Breadth:**
#     *   **Data Analysis:** Presented as more focused and specific, often answering particular questions or solving defined problems.
#     *   **Data Science:** Described as broader in scope, encompassing data analysis but also including predictive modeling, machine learning, and the creation of data-driven products.
#
# 3.  **Techniques and Tools:**
#     *   **Data Analysis:** Emphasizes descriptive statistics, data visualization, and basic statistical methods. Tools include Excel, SQL, and basic Python/R libraries.
#     *   **Data Science:** Highlights advanced statistical programming, machine learning, and AI. Tools include Python, R, and specialized libraries for machine learning.
#
# 4.  **Objectives:**
#     *   **Data Analysis:** To extract actionable insights, summarize
#
#
# === 🔄 Consensus Analysis ===
# Okay, let's analyze the three expert responses on the differences between Data Analysis and Data Science.
#
# **Consensus Analysis:**
#
# All three experts agree on the fundamental distinction:
#
# *   **Data Analysis:** Focuses on understanding *past* and *present* data to extract insights, answer specific questions, and support decision-making. It's about describing what happened and why.
# *   **Data Science:** Focuses on using data to predict *future* outcomes, build models, and create data-driven products. It's about what *could* happen and how to make it happen.
#
# Here's a breakdown of the common points:
#
# *   **Objective:** Data analysis aims to understand and explain, while data science aims to predict and create.
# *   **Scope:** Data analysis is more focused and specific, often dealing with historical data and answering defined questions. Data science is broader, encompassing analysis but also predictive modeling and algorithm development.
# *   **Techniques:** Data analysis relies heavily on descriptive statistics, data visualization, and basic statistical methods. Data science uses more advanced techniques like machine learning, AI, and complex statistical modeling.
# *   **Tools:** Data analysis commonly uses tools like Excel, SQL, and basic Python/R libraries. Data science uses more advanced programming languages (Python, R) and specialized libraries for machine learning and AI.
# *   **Outcome:** Data analysis produces reports, dashboards, and visualizations. Data science produces predictive models, algorithms, and data-driven products.
# *   **Skillset:** Data analysis requires strong analytical, statistical, and data visualization skills. Data science requires a broader skillset, including advanced programming, machine learning, and statistical modeling.
#
# **Disagreements and Nuances:**
#
# While the core concepts are consistent, there are some subtle differences in emphasis:
#
# *   **xAI** emphasizes the "cleaning" and "transforming" aspects of data analysis, which are also important but not as explicitly highlighted by OpenAI and Anthropic.
# *   **Anthropic** uses a more creative, metaphorical approach ("Detective" vs. "Visionary Architect"), which is helpful for understanding the different mindsets but might be less precise than the other two.
# *   **OpenAI** provides a more structured and detailed breakdown of the techniques and tools used in each field.
# *   **xAI** explicitly mentions "basic machine learning techniques" as part of data analysis, which could be a point of debate. While some basic ML might

# %%
from rich.console import Console
from rich.markdown import Markdown

console = Console()

# Header for the entire output
console.print("[bold blue]=== Workflow Results ===[/bold blue]")
console.print(f"[italic]Query:[/italic] {query_example}\n")

# 1. Display Expert Responses
console.print("[bold green]=== Expert Responses ===[/bold green]")
for expert, response in {k: v for k, v in results.items() if k.endswith("Response")}.items():
    console.print(f"[bold]{expert.replace('_Response', '')}:[/bold]")
    console.print(response)
    console.print("\n")

# 2. Display Consensus Analysis
if "Consensus_Analysis" in results:
    console.print("[bold magenta]=== Consensus Analysis ===[/bold magenta]")
    console.print(Markdown(results["Consensus_Analysis"]))
    console.print("\n")

# 3. Display Other Sections with Markdown Rendering
sections = {
    "Charts_Mindmaps": "Charts and Mindmaps",
    "Analysis_Tools": "Analysis Tools",
    "Related_Questions": "Related Questions",
    "Meta_Analysis": "Meta Analysis"
}

for key, title in sections.items():
    console.print(f"[bold yellow]=== {title} ===[/bold yellow]")
    console.print("\n")
    console.print(Markdown(results[key]))
    console.print("\n")
    console.print("\n")
    console.print("\n")
# Out:
# === Workflow Results ===
# Query: Explain how Data analysis and data science are different
# === Expert Responses ===
# === Consensus Analysis ===
# Okay, let's analyze the three expert responses on the differences between Data Analysis and Data Science.
#
# Consensus Analysis:
#
# All three experts agree on the fundamental distinction:
#
#  • Data Analysis: Focuses on understanding past and present data to extract insights, answer specific questions,
#    and support decision-making. It's about describing what happened and why.
#  • Data Science: Focuses on using data to predict future outcomes, build models, and create data-driven products.
#    It's about what could happen and how to make it happen.
#
# Here's a breakdown of the common points:
#
#  • Objective: Data analysis aims to understand and explain, while data science aims to predict and create.
#  • Scope: Data analysis is more focused and specific, often dealing with historical data and answering defined
#    questions. Data science is broader, encompassing analysis but also predictive modeling and algorithm
#    development.
#  • Techniques: Data analysis relies heavily on descriptive statistics, data visualization, and basic statistical
#    methods. Data science uses more advanced techniques like machine learning, AI, and complex statistical modeling.
#  • Tools: Data analysis commonly uses tools like Excel, SQL, and basic Python/R libraries. Data science uses more
#    advanced programming languages (Python, R) and specialized libraries for machine learning and AI.
#  • Outcome: Data analysis produces reports, dashboards, and visualizations. Data science produces predictive
#    models, algorithms, and data-driven products.
#  • Skillset: Data analysis requires strong analytical, statistical, and data visualization skills. Data science
#    requires a broader skillset, including advanced programming, machine learning, and statistical modeling.
#
# Disagreements and Nuances:
#
# While the core concepts are consistent, there are some subtle differences in emphasis:
#
#  • xAI emphasizes the "cleaning" and "transforming" aspects of data analysis, which are also important but not as
#    explicitly highlighted by OpenAI and Anthropic.
#  • Anthropic uses a more creative, metaphorical approach ("Detective" vs. "Visionary Architect"), which is helpful
#    for understanding the different mindsets but might be less precise than the other two.
#  • OpenAI provides a more structured and detailed breakdown of the techniques and tools used in each field.
#  • xAI explicitly mentions "basic machine learning techniques" as part of data analysis, which could be a point of
#    debate. While some basic ML might
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# === Charts and Mindmaps ===
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Okay, here are descriptions for charts or mindmaps summarizing the differences between Data Analysis and Data
# Science, based on the provided text:
#
# Chart 1: Venn Diagram
#
#  • Description: A Venn diagram with two overlapping circles. One circle is labeled "Data Analysis" and the other
#    "Data Science." The overlapping section represents shared skills and techniques.
#     • Data Analysis Circle:  Key points: "Focus: Insights from existing data," "Scope: Specific questions,"
#       "Techniques: Descriptive statistics, visualization," "Outcome: Reports, dashboards."
#     • Data Science Circle: Key points: "Focus: Data-driven products," "Scope: Predictive modeling," "Techniques:
#       Machine learning, advanced algorithms," "Outcome: AI models, predictive systems."
#     • Overlap:  Key points: "Data manipulation," "Statistical methods," "Programming (Python, R)."
#
# Chart 2:  Side-by-Side Comparison Table
#
#  • Description: A table with two columns, "Data Analysis" and "Data Science," and rows for key comparison points.
#     • Rows:
#        • Objective: (Data Analysis: Extract insights, answer questions; Data Science: Create data-driven products,
#          predict future)
#        • Scope: (Data Analysis: Focused, specific; Data Science: Broad, predictive)
#        • Techniques: (Data Analysis: Descriptive statistics, visualization; Data Science: Machine learning,
#          advanced algorithms)
#        • Tools: (Data Analysis: Excel, SQL, BI tools; Data Science: Python, R, advanced programming)
#        • Outcome: (Data Analysis: Reports, dashboards; Data Science: AI models, predictive systems)
#        • Skillset: (Data Analysis: Analytical, statistical; Data Science: Interdisciplinary, advanced technical)
#
# Chart 3: Mind Map
#
#  • Description: A central node labeled "Data Analysis vs. Data Science." Two main branches extend from it.
#     • Branch 1: Data Analysis:
#        • Sub-branches: "Objective: Understand past," "Scope: Specific," "Techniques: Descriptive," "Tools: SQL,
#          Excel," "Outcome: Reports," "Skills: Statistical, analytical."
#     • Branch 2: Data Science:
#        • Sub-branches: "Objective: Predict future," "Scope: Broad,"
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# === Analysis Tools ===
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Okay, let's break down this text with sentiment analysis, bias detection, uncertainty highlighting, and jargon
# explanation.
#
#
#                                                 Sentiment Analysis
#
# Overall, the sentiment of the text is neutral and objective. It aims to provide a factual comparison between data
# analysis and data science. There are no strong positive or negative emotions expressed. The language is descriptive
# and informative, focusing on the differences in scope, techniques, objectives, and outcomes of each field.
#
#  • OpenAI: The tone is very formal and structured, using numbered lists and clear headings.
#  • Anthropic: The tone is more creative and metaphorical, using analogies like "detective" and "visionary
#    architect." This adds a slightly more engaging feel but still remains neutral in sentiment.
#  • xAI: The tone is similar to OpenAI, using a structured approach with headings and bullet points. It is also
#    neutral and objective.
#
#
#                                                   Bias Detection
#
# There is minimal overt bias in the text. However, some subtle biases might be present:
#
#  • Implicit Hierarchy: The way the information is presented might subtly imply that data science is "more advanced"
#    or "more important" than data analysis. This is particularly noticeable in the Anthropic section, where data
#    science is described as "visionary architect" and data analysis as "detective." This could be interpreted as a
#    bias towards the more complex and future-oriented field.
#  • Tool Emphasis: The text lists specific tools for each field. While this is informative, it could inadvertently
#    create a bias towards certain technologies. For example, the emphasis on Python and R for data science might
#    suggest that these are the only valid tools, which is not necessarily true.
#  • Scope Framing: The framing of data science as "predictive and prescriptive" and data analysis as "descriptive
#    and diagnostic" could be seen as a bias towards future-oriented work. This might undervalue the importance of
#    understanding past and present data.
#
# Mitigation: It's important to note that these are subtle biases and not necessarily intentional. The text is
# primarily descriptive. However, readers should be aware that the way information is framed can influence
# perception.
#
#
#                                              Uncertainty Highlighting
#
# There is very little uncertainty expressed in the text. The information is presented as factual and definitive.
# However, some areas where uncertainty could be considered:
#
#  • "Typical Tasks": The lists of typical tasks are not exhaustive and might not apply to all situations. The use of
#    "typical" implies that there are
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# === Related Questions ===
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Okay, here are some learning questions based on the provided text, designed to encourage deeper understanding and
# critical thinking about the differences between data analysis and data science. I've categorized them for clarity:
#
# Understanding Core Concepts:
#
#  • Question 1: The texts mention that data analysis is often about "what happened" and "why it happened," while
#    data science is about "predicting future scenarios." Can you provide a real-world example of a business problem
#    where both data analysis and data science would be used, and explain how each would contribute?
#     • Deeper Learning: This question encourages applying the concepts to a practical situation, highlighting the
#       complementary nature of the two fields.
#  • Question 2: All three texts mention "descriptive statistics" as a key technique in data analysis. What are some
#    examples of descriptive statistics, and why are they so important for understanding data?
#     • Deeper Learning: This prompts a deeper dive into a specific technique, encouraging understanding of its
#       purpose and application.
#  • Question 3: The texts list various tools used in both data analysis and data science. Why are tools like Python
#    and R more commonly associated with data science, while tools like Excel are more often used in data analysis?
#     • Deeper Learning: This question encourages thinking about the capabilities of different tools and why they are
#       suited to different tasks.
#  • Question 4: The Anthropic text uses the metaphors of a "detective" for data analysis and a "visionary architect"
#    for data science. How do these metaphors help to illustrate the differences in their roles and objectives?
#     • Deeper Learning: This encourages thinking about the abstract concepts through the lens of metaphors,
#       enhancing understanding.
#
# Comparing and Contrasting:
#
#  • Question 5: The texts highlight that data science involves "predictive modeling" and "machine learning." How do
#    these techniques differ from the statistical methods used in data analysis, and why are they important for
#    future-oriented tasks?
#     • Deeper Learning: This question encourages a deeper understanding of the techniques used in data science and
#       their purpose.
#  • Question 6: The xAI text mentions that data analysis focuses on "cleaning" and "transforming" data. Why is this
#    step so crucial, and how does it impact the quality of the insights derived from the data?
#     • Deeper Learning: This question highlights the importance of data
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# === Meta Analysis ===
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Okay, let's analyze these three texts describing the differences between Data Analysis and Data Science. Here's a
# breakdown of my evaluation, focusing on quality metrics and pattern recognition:
#
# Overall Quality Assessment:
#
#  • Clarity and Conciseness: All three texts do a reasonably good job of explaining the core differences. OpenAI's
#    is structured with numbered points, Anthropic uses a creative analogy, and xAI uses a more traditional
#    breakdown. All are relatively easy to understand.
#  • Accuracy: The information presented is generally accurate and aligns with common understanding of the two
#    fields. There are no major factual errors.
#  • Completeness: Each text covers the key aspects of both data analysis and data science, including objectives,
#    scope, techniques, tools, outcomes, and required skill sets.
#  • Consistency: There is a high degree of consistency across the three texts in terms of the core differences they
#    highlight. They all agree on the fundamental distinctions.
#  • Bias: There is no apparent bias in any of the texts. They present the information objectively.
#
# Pattern Recognition and Key Themes:
#
# Here are the recurring themes and patterns I've identified:
#
#  1 Focus on Past vs. Future:
#     • Data Analysis: Consistently described as focused on understanding past or current data. It's about what has
#       happened and why. The goal is to extract insights from existing data.
#     • Data Science: Described as forward-looking, focusing on predicting future outcomes and building models. It's
#       about what could happen and how to influence it.
#  2 Scope and Breadth:
#     • Data Analysis: Presented as more focused and specific, often answering particular questions or solving
#       defined problems.
#     • Data Science: Described as broader in scope, encompassing data analysis but also including predictive
#       modeling, machine learning, and the creation of data-driven products.
#  3 Techniques and Tools:
#     • Data Analysis: Emphasizes descriptive statistics, data visualization, and basic statistical methods. Tools
#       include Excel, SQL, and basic Python/R libraries.
#     • Data Science: Highlights advanced statistical programming, machine learning, and AI. Tools include Python, R,
#       and specialized libraries for machine learning.
#  4 Objectives:
#     • Data Analysis: To extract actionable insights, summarize
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
